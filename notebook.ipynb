# %% [markdown]
# # MLOps Social Sentiment Monitoring
# Notebook di esecuzione rapida per Colab. Clona il repo, installa le dipendenze e lancia download + training.

# %% [markdown]
# ## Setup
# Clona il repository in questa sessione di Colab. Se hai gia' clonato, il comando non lo scarica di nuovo.

# %%
import os
REPO_URL = "https://github.com/wil-nep/MLOPs-social-sentiment-monitoring.git"
REPO_DIR = "MLOPs-social-sentiment-monitoring"
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL}
else:
    print(f"Repo gia' presente in {REPO_DIR}")
# %cd {REPO_DIR}
# !ls -la

# %% [markdown]
# ## Dipendenze
# Installa i requisiti del progetto.

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Download dataset
# Esegue lo script di download (usa training/download_dataset.py).

# %%
# !python training/download_dataset.py

# %% [markdown]
# ## Training modello
# Esegue lo script di training.

# %%
# !python training/train_model.py

# %% [markdown]
# ## Note
# - Per avviare l'API in Colab usa ad esempio: `!uvicorn app.main:app --host 0.0.0.0 --port 8000` (tenere la cella in esecuzione).
# - Aggiungi eventuali ulteriori esperimenti o valutazioni sotto.
